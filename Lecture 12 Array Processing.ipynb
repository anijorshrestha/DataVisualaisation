# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
points = np.arange(-5,5,0.01)

# %%
dx,dy = np.meshgrid(points, points)

# %%
dx
# Out:
# array([[-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        ...,
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99]])

# %%
dy
# Out:
# array([[-5.  , -5.  , -5.  , ..., -5.  , -5.  , -5.  ],
#        [-4.99, -4.99, -4.99, ..., -4.99, -4.99, -4.99],
#        [-4.98, -4.98, -4.98, ..., -4.98, -4.98, -4.98],
#        ...,
#        [ 4.97,  4.97,  4.97, ...,  4.97,  4.97,  4.97],
#        [ 4.98,  4.98,  4.98, ...,  4.98,  4.98,  4.98],
#        [ 4.99,  4.99,  4.99, ...,  4.99,  4.99,  4.99]])

# %%
z= (np.sin(dx) + np.sin(dy))
z
# Out:
# array([[ 1.91784855e+00,  1.92063718e+00,  1.92332964e+00, ...,
#         -8.07710558e-03, -5.48108704e-03, -2.78862876e-03],
#        [ 1.92063718e+00,  1.92342581e+00,  1.92611827e+00, ...,
#         -5.28847682e-03, -2.69245827e-03, -5.85087534e-14],
#        [ 1.92332964e+00,  1.92611827e+00,  1.92881072e+00, ...,
#         -2.59601854e-03, -5.63993297e-14,  2.69245827e-03],
#        ...,
#        [-8.07710558e-03, -5.28847682e-03, -2.59601854e-03, ...,
#         -1.93400276e+00, -1.93140674e+00, -1.92871428e+00],
#        [-5.48108704e-03, -2.69245827e-03, -5.63993297e-14, ...,
#         -1.93140674e+00, -1.92881072e+00, -1.92611827e+00],
#        [-2.78862876e-03, -5.85087534e-14,  2.69245827e-03, ...,
#         -1.92871428e+00, -1.92611827e+00, -1.92342581e+00]])

# %%
  plt.imshow(z)

# %%
plt.imshow(z)
plt.colorbar()
plt.title('Plot for sin(x)+sin(y) ')
# Out:
# Text(0.5, 1.0, 'Plot for sin(x)+sin(y) ')

# %%
# numpy where
A= np.array([1,2,3,4])
B= np.array([100,200,300,400])

# %%
condition=np.array([True,True,False,False])

# %%
answer = [(A_val if cond else B_val) for A_val,B_val,cond in zip(A,B,condition)]

# %%
answer
# Out:
# [1, 2, 300, 400]

# %%
answer2=np.where(condition,A,B)
answer2
# Out:
# array([  1,   2, 300, 400])

# %%
from numpy.random import randn

# %%
arr=randn(5,5)
arr
# Out:
# array([[-0.07182982,  1.13202285, -1.82875026, -2.04957699,  1.12447232],
#        [-0.49478146,  2.36070371,  1.60348861,  0.28233692, -0.90103759],
#        [-0.51312905,  2.10023945, -0.61048986,  1.92492725,  0.37031571],
#        [ 0.61444417,  0.22827569,  0.35747736, -0.49065374,  1.03644727],
#        [-0.29945887, -2.30556242, -0.62423734,  1.6168999 ,  1.8481588 ]])

# %%
np.where(arr<0,0,arr)
# Out:
# array([[0.        , 1.13202285, 0.        , 0.        , 1.12447232],
#        [0.        , 2.36070371, 1.60348861, 0.28233692, 0.        ],
#        [0.        , 2.10023945, 0.        , 1.92492725, 0.37031571],
#        [0.61444417, 0.22827569, 0.35747736, 0.        , 1.03644727],
#        [0.        , 0.        , 0.        , 1.6168999 , 1.8481588 ]])

# %%
np.where(arr<0,1,arr)
arr
# Out:
# array([[-0.07182982,  1.13202285, -1.82875026, -2.04957699,  1.12447232],
#        [-0.49478146,  2.36070371,  1.60348861,  0.28233692, -0.90103759],
#        [-0.51312905,  2.10023945, -0.61048986,  1.92492725,  0.37031571],
#        [ 0.61444417,  0.22827569,  0.35747736, -0.49065374,  1.03644727],
#        [-0.29945887, -2.30556242, -0.62423734,  1.6168999 ,  1.8481588 ]])

# %%
np.where(arr>0,1,arr)
# Out:
# array([[-0.07182982,  1.        , -1.82875026, -2.04957699,  1.        ],
#        [-0.49478146,  1.        ,  1.        ,  1.        , -0.90103759],
#        [-0.51312905,  1.        , -0.61048986,  1.        ,  1.        ],
#        [ 1.        ,  1.        ,  1.        , -0.49065374,  1.        ],
#        [-0.29945887, -2.30556242, -0.62423734,  1.        ,  1.        ]])

# %%
 countries=np.array(['France','Germany','USA','Russia','Mexico','USA'])

# %%
countries.any()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-c00cb2dcc616> in <module>
# ----> 1 countries.any()
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _any(a, axis, dtype, out, keepdims)
#      41
#      42 def _any(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 43     return umr_any(a, axis, dtype, out, keepdims)
#      44
#      45 def _all(a, axis=None, dtype=None, out=None, keepdims=False):
#
# TypeError: cannot perform reduce with flexible type

# %%
 np.in1d(['France','Sweden'],countries)
# Out:
# array([ True, False])

# %%
np.unique(countries)
# Out:
# array(['France', 'Germany', 'Mexico', 'Russia', 'USA'], dtype='<U7')
